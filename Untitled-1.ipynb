# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import fftconvolve
import IPython
import pyroomacoustics as pra

# %% [markdown]
# Создаем модель комнаты

# %%
# Задаю ее размеры
corners = np.array([[0,0], [0, 3.1], [4.1, 3.1], [4.1, 1.6], [3.5, 1.6], [3.5, 0]]).T
room = pra.Room.from_corners(corners)
room.extrude(2.)

# Устанавливаю ограничения
fig, ax = room.plot()
ax.set_xlim([0, 4.5])
ax.set_ylim([0, 3.5])
ax.set_zlim([0, 2])
# Out:
# (0.0, 2.0)

# %%
fs, signal = wavfile.read("arctic_a0010.wav")
fs, noise = wavfile.read("arctic_b0539.wav")

# Добавляем источник звука
room_bf = pra.ShoeBox([4.1, 3.1], fs=fs, max_order=12)
source = np.array([2, 1])
interferer = np.array([3.5, 2])
room_bf.add_source(source, delay=0, signal=signal)
room_bf.add_source(interferer, delay=0, signal=noise[:len(signal)])


#Создаем микрофонную решетку
Lg_t = 0.1
Lg = np.ceil(Lg_t*fs)

center = [1, 2.7]; radius = 37.5e-3
fft_len = 512
echo = pra.circular_2D_array(center=center, M=4, phi0=0, radius=radius)
echo = np.concatenate((echo, np.array(center, ndmin=2).T), axis=1)
mics = pra.Beamformer(echo, room_bf.fs, N=fft_len, Lg=Lg)
room_bf.add_microphone_array(mics)

mics.rake_delay_and_sum_weights(room_bf.sources[0][:1])

room_bf.simulate()


fig, ax = room_bf.plot(freq=[500, 1000, 2000, 4000], img_order=0)
ax.legend(['500', '1000', '2000', '4000'])
fig.set_size_inches(20, 8)

# %%
# Location of sources
azimuth = np.array([61., 270.]) / 180. * np.pi
distance = 2.  # meters

# %%
c = 343.    # speed of sound
freq_range = [300, 3500]

snr_db = 5.    # signal-to-noise ratio
sigma2 = 10**(-snr_db / 10) / (4. * np.pi * distance)**2

X = pra.transform.stft.analysis(room_bf.mic_array.signals.T, fft_len, fft_len // 2)
X = X.transpose([2, 0, 1])

time_idx = 1
freq_idx = 2
X_freq = X[time_idx, freq_idx, :]

X_freq = X_freq.reshape(-1, 1)

# %%
def ESPRIT(signal_matrix, num_source=1):
    
    M,t = signal_matrix.shape

    x = signal_matrix @ signal_matrix.conj().T/t  #ковариац матрица
    _, y = np.linalg.eigh(x) #раскладываю по собю значениям
    Ys = y[:,:-num_source] #выделяю подпространство

    
    Ys1 = Ys[:-1, :]
    Ys2 = Ys[1:, :]

    a = np.linalg.pinv(Ys1) @ Ys2

    eigvals = np.linalg.eigvals(a)  #собсственная матрица
    angle = np.angle(eigvals)  #собственные значения

    return angle * 180 / np.pi

angles = ESPRIT(X_freq)
print(angles)
estimated_angle = angles[0]
# Out:
# [ 169.32692066 -120.85775177   83.12132133   75.66976129   55.70077868
#    43.79912264  114.61218608   67.53174458   69.06673875   70.68295638
#    72.23938506   73.80765374   75.74114237   79.33721131   77.38546208
#    79.75768023   81.27399071   83.24855612   84.08728347   87.45394538
#    86.08452149   89.22333292   90.60245648   92.24075476   93.80705636
#    96.71982778   95.68083386   98.21529029   98.90844817  108.70082934
#   100.71024092  102.4462255   104.34632255  105.57274505   57.88658963
#    59.83917673   61.55021485   62.86495071   65.97793836   33.57565446
#   107.47050991   54.91011762   53.72190316   56.53272466   64.23503926
#   109.50865792   51.81981795  111.21679885   50.46008646   48.70755103
#   112.91207947  130.46755603   47.08450397  115.0722834   145.87545735
#    45.32649177  165.37825857   28.90822596   43.90730202  116.81805786
#   118.28512403  120.00846928  121.77244382  123.60188264  126.81343001
#   125.01701036   42.08828402   40.75849755   26.76132623   38.78974735
#    37.4098038    35.66408298   34.04992416   32.20494448   30.5906937
#    28.47022093  128.36541707   25.17870884   16.54019633   23.65793519
#    20.0261328   139.65963784  136.58337441  135.08064646  130.24612775
#   131.67379726  137.78855726  140.97668981  142.81920497  144.3604807
#   133.6792136    21.74425722   18.99516314   17.46453321   15.6244516
#    13.94046232  146.05555707   12.2483863    10.72270187  154.05777874
#   152.77867988  151.02148061  149.36230925  -47.69237582 -133.70259209
#     7.5296035     8.86974076 -151.10289157 -167.9312335  -179.25472885
#   155.88873451  157.60731537  159.04922392  -72.9136123   -56.71850003
#     6.6245876  -113.9999683   172.13652431 -148.21037778 -150.23696205
#  -151.84821803 -153.7512518  -155.24727842 -156.9991728    -9.14986696
#  -101.89744972 -121.44881205 -146.93192394 -158.43776317  160.75312857
#  -124.29665841 -160.09839776 -144.95998453 -144.01170552 -161.72303513
#  -132.17904653 -120.43157785 -122.31176755 -125.69092796 -118.78220431
#   -27.17641826  -38.46375386 -163.39778728 -142.14782767 -117.02389915
#  -131.65756066 -129.50605209 -115.34225483 -167.09008598 -127.96886817
#  -113.36988364  -40.30321342  -43.72720991  -42.07709814  -47.17232834
#   -45.50619475  -48.97140378  -50.61862073  -52.51847083 -140.37852903
#  -169.69676088  -54.1156135   -38.49079815  162.14484868 -171.15584987
#  -167.92071483 -111.75207687 -133.3311186     3.42505273    2.19035086
#  -174.35792692 -173.27154239 -109.94038658 -139.01873416  -60.07996941
#   -56.09548365  -36.45308567  -57.90719988  -85.00385573 -108.39951939
#   -34.97595505 -106.55591708  -60.87416882  163.72248358    0.69970542
#  -135.20469335 -175.90538652  168.82822099  -33.26015062 -105.20719846
#   -64.84971695  -66.65553197  -62.68464544  -68.76711939  -72.23196129
#    -0.82442267  -31.72741027  -88.6323861   -70.43425041  147.6914984
#   170.41089668  171.63067216   -2.3500398   -30.23356236  -86.52512823
#   -85.11611715  -90.37638594  -90.18465386 -102.14615244 -100.34845805
#   -98.78992258  -72.73349557  -83.38854261  -92.30855608 -177.34352362
#   173.99891445   -4.13873836 -137.25229802  -96.36895058  -81.34760077
#   -28.34246811  175.65408378  123.28268098  166.84547806  -60.83219882
#   -26.75177977  -74.4858241    -9.03978904  -10.82311467   -5.60899235
#    -7.41544188  -12.20017437  -22.59503851  -95.53539494  -21.12436325
#  -179.34852081  177.34931458 -134.70390625  -79.73049153  -24.03647072
#   -94.20761811  -26.32037607  -14.07072246  -15.52138621  165.5631559
#     5.17099676 -165.29842868 -103.31034393  -78.03522136  -17.55070657
#   178.86492416  -18.97591408  -76.39007716  -67.55591244  -19.92180886
#   155.70108111]
